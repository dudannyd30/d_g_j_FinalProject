# %%
import pandas as pd

# pull from Kaggle 
aviation_df = pd.read_csv('/Users/danieldaquila/Documents/GradSchool/COMP4447/homeworks/Final_Project/AviationData.csv', encoding="ISO-8859-1")

aviation_df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20181217X10943           Accident      GAA19CA098  2018-12-16
# 1  20181217X25746           Accident      GAA19CA097  2018-12-15
# 2  20181213X41114           Accident      ERA19LA065  2018-12-13
# 3  20181213X45528           Accident      CEN19FA044  2018-12-13
# 4  20181214X90303           Accident      GAA19CA096  2018-12-11
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0   Grangville, ID  United States  45.583611 -115.681667          PVT
# 1     MORIARTY, NM  United States  34.970000 -106.000000          NaN
# 2  Punta Gorda, FL  United States  26.925278  -82.001111          PGD
# 3   Valparaiso, IN  United States  41.451667  -87.004444          VPZ
# 4     Hartford, WI  United States  43.330278  -88.326111          HXF
#
#          Airport.Name  ... Purpose.of.Flight Air.Carrier Total.Fatal.Injuries  \
# ...

# %%
aviation_df.drop(['Investigation.Type', 'Airport.Code', 'Airport.Name', 'Engine.Type', 'FAR.Description', 'Schedule', 'Air.Carrier', 'Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured', 'Report.Status', 'Publication.Date'], axis=1, inplace=True)
aviation_df
# Out:
#              Event.Id Accident.Number  Event.Date         Location  \
# 0      20181217X10943      GAA19CA098  2018-12-16   Grangville, ID
# 1      20181217X25746      GAA19CA097  2018-12-15     MORIARTY, NM
# 2      20181213X41114      ERA19LA065  2018-12-13  Punta Gorda, FL
# 3      20181213X45528      CEN19FA044  2018-12-13   Valparaiso, IN
# 4      20181214X90303      GAA19CA096  2018-12-11     Hartford, WI
# ...               ...             ...         ...              ...
# 82630  20041105X01764      CHI79FA064  1979-08-02       Canton, OH
# 82631  20001218X45448      LAX96LA321  1977-06-19       EUREKA, CA
# 82632  20061025X01555      NYC07LA005  1974-08-30    Saltville, VA
# 82633  20001218X45447      LAX94LA336  1962-07-19   BRIDGEPORT, CA
# 82634  20001218X45444      SEA87LA080  1948-10-24  MOOSE CREEK, ID
#
#              Country   Latitude   Longitude Injury.Severity Aircraft.Damage  \
# 0      United States  45.583611 -115.681667       Non-Fatal     Substantial
# ...

# %% [markdown]
# ## List the reason for dropping each column here

# %%
aviation_df.isna().sum()
# Out:
# Event.Id                     0
# Accident.Number              0
# Event.Date                   0
# Location                    75
# Country                    507
# Latitude                 53903
# Longitude                53912
# Injury.Severity              0
# Aircraft.Damage           2592
# Aircraft.Category        56735
# Registration.Number       3582
# Make                        73
# Model                      102
# Amateur.Built              627
# Number.of.Engines         4609
# Purpose.of.Flight         4550
# Weather.Condition         2708
# Broad.Phase.of.Flight     6503
# dtype: int64

# %%
aviation_df = aviation_df.rename(columns={"Event.Id":"Event_ID", "Accident.Number":"Accident_Number", "Event.Date":"Event_Date", "Injury.Severity":"Injury_Severity", "Aircraft.Damage":"Aircraft_Damage", "Aircaft.Category":"Aircraft_Category", "Registration.Number":"Registration_Number", "Amateur.Built":"Amateur_Built", "Number.of.Engines":"Number_Engines", "Purpose.of.Flight":"Purpose_Flight", "Weather.Condition":"Weather_Condition", "Broad.Phase.of.Flight":"Broad_Phase_Flight"})
aviation_df
# Out:
#              Event_ID Accident_Number  Event_Date         Location  \
# 0      20181217X10943      GAA19CA098  2018-12-16   Grangville, ID
# 1      20181217X25746      GAA19CA097  2018-12-15     MORIARTY, NM
# 2      20181213X41114      ERA19LA065  2018-12-13  Punta Gorda, FL
# 3      20181213X45528      CEN19FA044  2018-12-13   Valparaiso, IN
# 4      20181214X90303      GAA19CA096  2018-12-11     Hartford, WI
# ...               ...             ...         ...              ...
# 82630  20041105X01764      CHI79FA064  1979-08-02       Canton, OH
# 82631  20001218X45448      LAX96LA321  1977-06-19       EUREKA, CA
# 82632  20061025X01555      NYC07LA005  1974-08-30    Saltville, VA
# 82633  20001218X45447      LAX94LA336  1962-07-19   BRIDGEPORT, CA
# 82634  20001218X45444      SEA87LA080  1948-10-24  MOOSE CREEK, ID
#
#              Country   Latitude   Longitude Injury_Severity Aircraft_Damage  \
# 0      United States  45.583611 -115.681667       Non-Fatal     Substantial
# ...

# %%
aviation_df['Aircraft_Damage'].unique()
# Out:
# array(['Substantial', 'Destroyed', 'Minor', nan], dtype=object)
